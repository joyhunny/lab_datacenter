# %%
import pandas as pd

# %%
train = pd.read_csv("data/train.tsv",sep='\t',index_col ='PhraseId' )

print(train.shape)
train.head()
# Out:
# (156060, 3)
#           SentenceId                                             Phrase  \
# PhraseId
# 1                  1  A series of escapades demonstrating the adage ...
# 2                  1  A series of escapades demonstrating the adage ...
# 3                  1                                           A series
# 4                  1                                                  A
# 5                  1                                             series
#
#           Sentiment
# PhraseId
# 1                 1
# 2                 2
# 3                 2
# 4                 2
# 5                 2

# %%
test = pd.read_csv('data/test.tsv',sep='\t',index_col='PhraseId')

print(test.shape)
train.head()
# Out:
# (66292, 2)
#           SentenceId                                             Phrase  \
# PhraseId
# 1                  1  A series of escapades demonstrating the adage ...
# 2                  1  A series of escapades demonstrating the adage ...
# 3                  1                                           A series
# 4                  1                                                  A
# 5                  1                                             series
#
#           Sentiment
# PhraseId
# 1                 1
# 2                 2
# 3                 2
# 4                 2
# 5                 2

# %% [markdown]
# ## Preprocessing

# %%
train['Phrase(origin)'] = train['Phrase'].copy()

print(train.shape)
train[['Phrase','Phrase(origin)']].head()
# Out:
# (156060, 4)
#                                                      Phrase  \
# PhraseId
# 1         A series of escapades demonstrating the adage ...
# 2         A series of escapades demonstrating the adage ...
# 3                                                  A series
# 4                                                         A
# 5                                                    series
#
#                                              Phrase(origin)
# PhraseId
# 1         A series of escapades demonstrating the adage ...
# 2         A series of escapades demonstrating the adage ...
# 3                                                  A series
# 4                                                         A
# 5                                                    series

# %%
test['Phrase(origin)'] = test['Phrase'].copy()

print(train.shape)
test[['Phrase','Phrase(origin)']].head()
# Out:
# (156060, 4)
#                                                      Phrase  \
# PhraseId
# 156061    An intermittently pleasing but mostly routine ...
# 156062    An intermittently pleasing but mostly routine ...
# 156063                                                   An
# 156064    intermittently pleasing but mostly routine effort
# 156065           intermittently pleasing but mostly routine
#
#                                              Phrase(origin)
# PhraseId
# 156061    An intermittently pleasing but mostly routine ...
# 156062    An intermittently pleasing but mostly routine ...
# 156063                                                   An
# 156064    intermittently pleasing but mostly routine effort
# 156065           intermittently pleasing but mostly routine

# %% [markdown]
# ## Clean Test

# %%
def clean_text(phrase):
    phrase = phrase.replace("doesn't","does not")
    phrase = phrase.replace("ca n't","can not")
    phrase = phrase.replace(" n't "," not ")
    
    return phrase

train['Phrase'] = train["Phrase"].apply(clean_text)

print(train.shape)
train[['Phrase','Phrase(origin)']].head()
# Out:
# (156060, 4)
#                                                      Phrase  \
# PhraseId
# 1         A series of escapades demonstrating the adage ...
# 2         A series of escapades demonstrating the adage ...
# 3                                                  A series
# 4                                                         A
# 5                                                    series
#
#                                              Phrase(origin)
# PhraseId
# 1         A series of escapades demonstrating the adage ...
# 2         A series of escapades demonstrating the adage ...
# 3                                                  A series
# 4                                                         A
# 5                                                    series

# %%
test['Phrase'] = test['Phrase'].apply(clean_text)

print(test.shape)
test.head()
# Out:
# (66292, 3)
#           SentenceId                                             Phrase  \
# PhraseId
# 156061          8545  An intermittently pleasing but mostly routine ...
# 156062          8545  An intermittently pleasing but mostly routine ...
# 156063          8545                                                 An
# 156064          8545  intermittently pleasing but mostly routine effort
# 156065          8545         intermittently pleasing but mostly routine
#
#                                              Phrase(origin)
# PhraseId
# 156061    An intermittently pleasing but mostly routine ...
# 156062    An intermittently pleasing but mostly routine ...
# 156063                                                   An
# 156064    intermittently pleasing but mostly routine effort
# 156065           intermittently pleasing but mostly routine

# %% [markdown]
# ## Vectorize phrases

# %%
from sklearn.feature_extraction.text import CountVectorizer
# http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html
# binary=True/False
# lowercase=True/False
# ngram_range=(1, 1)
# stop_words=None

vectorizer = CountVectorizer(max_features=20000,ngram_range=(1,2))
vectorizer
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=20000, min_df=1,
#         ngram_range=(1, 2), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
vectorizer.fit(train['Phrase'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=20000, min_df=1,
#         ngram_range=(1, 2), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
aa = vectorizer.get_feature_names()
aa.index('diappointments')

# help(list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-b1b478e49d71> in <module>()
#       1 aa = vectorizer.get_feature_names()
# ----> 2 aa.index('diappointments')
#       3
#       4 # help(list)
#
# ValueError: 'diappointments' is not in list

# %%
x_train = vectorizer.transform(train['Phrase'])
x_train
# Out:
# <156060x20000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1322766 stored elements in Compressed Sparse Row format>

# %%
words_list = []
vocabulary = vectorizer.get_feature_names()

for i in range(x_train.shape[0])
    vector = x_train[i].toarray().reshape(-1)
    vocabulary_pairs = list(zip(vocabulary, vector))

    words = [word for word, count in vocabulary_pairs if count != 0]
    
    words_list.append(words)
    
words_list
# Out:
# [['also',
#   'amounts',
#   'amounts to',
#   'but',
#   'but none',
#   'for',
#   'for the',
#   'good',
#   'good for',
#   'goose',
#   'is',
#   'is also',
#   'is good',
#   'much',
#   'much of',
#   'none',
#   'none of',
#   'occasionally',
#   'of',
#   'of story',
#   'of which',
#   'series',
#   'series of',
#   'some',
#   'some of',
#   'story',
#   'that',
#   'the',
#   'to',
#   'to much',
#   'what',
#   'what is',
#   'which'],
#  ['for',
#   'for the',
#   'good',
#   'good for',
#   'goose',
#   'is',
#   'is good',
#   'of',
#   'series',
#   'series of',
#   'that',
#   'the',
#   'what',
#   'what is'],
#  ['series'],
#  [],
#  ['series'],
#  ['for',
#   'for the',
#   'good',
#   'good for',
#   'goose',
#   'is',
#   'is good',
#   'of',
#   'that',
#   'the',
#   'what',
#   'what is'],
#  ['of'],
#  ['for',
#   'for the',
#   'good',
#   'good for',
#   'goose',
#   'is',
#   'is good',
#   'that',
#   'the',
#   'what',
#   'what is'],
#  [],
#  ['for',
#   'for the',
#   'good',
#   'good for',
#   'goose',
#   'is',
#   'is good',
#   'that',
#   'the',
#   'what',
#   'what is'],
#  ['the'],
#  [],
#  ['the'],
#  ['the'],
#  [],
#  ['for',
#   'for the',
#   'good',
#   'good for',
#   'goose',
#   'is',
#   'is good',
#   'that',
#   'the',
#   'what',
#   'what is'],
#  ['that'],
#  ['for',
#   'for the',
#   'good',
#   'good for',
#   'goose',
#   'is',
#   'is good',
#   'the',
#   'what',
#   'what is'],
#  ['what'],
#  ['for', 'for the', 'good', 'good for', 'goose', 'is', 'is good', 'the'],
#  ['is'],
#  ['for', 'for the', 'good', 'good for', 'goose', 'the'],
#  ['good'],
#  ['for', 'for the', 'goose', 'the'],
#  ['for'],
#  ['goose', 'the'],
#  ['goose'],
#  ['also',
#   'amounts',
#   'amounts to',
#   'but',
#   'but none',
#   'for',
#   'for the',
#   'good',
#   'good for',
#   'is',
#   'is also',
#   'much',
#   'much of',
#   'none',
#   'none of',
#   'occasionally',
#   'of',
#   'of story',
#   'of which',
#   'some',
#   'some of',
#   'story',
#   'the',
#   'to',
#   'to much',
#   'which'],
#  ['also',
#   'amounts',
#   'amounts to',
#   'but',
#   'but none',
#   'for',
#   'for the',
#   'good',
#   'good for',
#   'is',
#   'is also',
#   'much',
#   'much of',
#   'none',
#   'none of',
#   'occasionally',
#   'of',
#   'of story',
#   'of which',
#   'some',
#   'some of',
#   'story',
#   'the',
#   'to',
#   'to much',
#   'which'],
#  ['also', 'is', 'is also'],
#  ['also'],
#  ['amounts',
#   'amounts to',
#   'but',
#   'but none',
#   'for',
#   'for the',
#   'good',
#   'good for',
#   'much',
#   'much of',
#   'none',
#   'none of',
#   'occasionally',
#   'of',
#   'of story',
#   'of which',
#   'some',
#   'some of',
#   'story',
#   'the',
#   'to',
#   'to much',
#   'which'],
#  ['amounts',
#   'amounts to',
#   'but',
#   'but none',
#   'for',
#   'for the',
#   'much',
#   'much of',
#   'none',
#   'none of',
#   'occasionally',
#   'of',
#   'of story',
#   'of which',
#   'some',
#   'some of',
#   'story',
#   'the',
#   'to',
#   'to much',
#   'which'],
#  ['amounts',
#   'amounts to',
#   'but',
#   'but none',
#   'much',
#   'much of',
#   'none',
#   'none of',
#   'occasionally',
#   'of',
#   'of story',
#   'of which',
#   'some',
#   'some of',
#   'story',
#   'the',
#   'to',
#   'to much',
#   'which'],
#  ['the'],
#  ['the'],
#  [],
#  [],
#  ['amounts',
#   'amounts to',
#   'but',
#   'but none',
#   'much',
#   'much of',
#   'none',
#   'none of',
#   'occasionally',
#   'of',
#   'of story',
#   'of which',
#   'some',
#   'some of',
#   'story',
#   'to',
#   'to much',
#   'which'],
#  ['of', 'of which', 'some', 'some of', 'which'],
#  ['some'],
#  ['of', 'of which', 'which'],
#  ['which'],
#  ['amounts',
#   'amounts to',
#   'but',
#   'but none',
#   'much',
#   'much of',
#   'none',
#   'none of',
#   'occasionally',
#   'of',
#   'of story',
#   'of which',
#   'story',
#   'to',
#   'to much',
#   'which'],
#  ['occasionally'],
#  ['amounts',
#   'amounts to',
#   'but',
#   'but none',
#   'much',
#   'much of',
#   'none',
#   'none of',
#   'of',
#   'of story',
#   'of which',
#   'story',
#   'to',
#   'to much',
#   'which'],
#  [],
#  ['amounts',
#   'amounts to',
#   'but',
#   'but none',
#   'much',
#   'much of',
#   'none',
#   'none of',
#   'of',
#   'of story',
#   'of which',
#   'story',
#   'to',
#   'to much',
#   'which'],
#  ['but'],
#  ['amounts',
#   'amounts to',
#   'much',
#   'much of',
#   'none',
#   'none of',
#   'of',
#   'of story',
#   'of which',
#   'story',
#   'to',
#   'to much',
#   'which'],
#  ['none'],
#  ['amounts',
#   'amounts to',
#   'much',
#   'much of',
#   'of',
#   'of story',
#   'of which',
#   'story',
#   'to',
#   'to much',
#   'which'],
#  ['amounts',
#   'amounts to',
#   'much',
#   'much of',
#   'of',
#   'of story',
#   'story',
#   'to',
#   'to much',
#   'which'],
#  ['amounts',
#   'amounts to',
#   'much',
#   'much of',
#   'of',
#   'of story',
#   'story',
#   'to',
#   'to much'],
#  ['amounts'],
#  ['much', 'much of', 'of', 'of story', 'story', 'to', 'to much'],
#  ['to'],
#  ['much', 'much of', 'of', 'of story', 'story'],
#  ['much'],
#  ['of', 'of story', 'story'],
#  ['story'],
#  ['story'],
#  [],
#  ['and',
#   'and entertaining',
#   'entertaining',
#   'independent',
#   'introspective',
#   'is',
#   'is worth',
#   'quiet',
#   'seeking',
#   'this',
#   'worth'],
#  ['and',
#   'and entertaining',
#   'entertaining',
#   'independent',
#   'introspective',
#   'quiet',
#   'this'],
#  ['this'],
#  ['and',
#   'and entertaining',
#   'entertaining',
#   'independent',
#   'introspective',
#   'quiet'],
#  ['and', 'and entertaining', 'entertaining', 'introspective', 'quiet'],
#  ['quiet'],
#  ['and', 'and entertaining', 'entertaining', 'introspective'],
#  ['and', 'and entertaining', 'entertaining', 'introspective'],
#  ['and', 'introspective'],
#  ['introspective'],
#  ['and'],
#  ['entertaining'],
#  ['independent'],
#  ['is', 'is worth', 'seeking', 'worth'],
#  ['is', 'is worth', 'seeking', 'worth'],
#  ['is', 'is worth', 'worth'],
#  ['worth'],
#  ['seeking'],
#  ['even',
#   'fans',
#   'fans of',
#   'hard',
#   'hard time',
#   'have',
#   'merchant',
#   'of',
#   'one',
#   'sitting',
#   'sitting through',
#   'suspect',
#   'this',
#   'this one',
#   'through',
#   'through this',
#   'time',
#   'work',
#   'would',
#   'would have'],
#  ['even', 'fans', 'fans of', 'merchant', 'of', 'work'],
#  ['even', 'fans'],
#  ['even'],
#  ['fans'],
#  ['merchant', 'of', 'work'],
#  ['merchant', 'work'],
#  ['merchant'],
#  [],
#  ['merchant'],
#  ['merchant'],
#  [],
#  ['work'],
#  ['hard',
#   'hard time',
#   'have',
#   'one',
#   'sitting',
#   'sitting through',
#   'suspect',
#   'this',
#   'this one',
#   'through',
#   'through this',
#   'time',
#   'would',
#   'would have'],
#  ['suspect'],
#  ['suspect'],
#  ['suspect'],
#  [],
#  ['suspect'],
#  ['hard',
#   'hard time',
#   'have',
#   'one',
#   'sitting',
#   'sitting through',
#   'this',
#   'this one',
#   'through',
#   'through this',
#   'time',
#   'would',
#   'would have'],
#  ['hard',
#   'hard time',
#   'have',
#   'one',
#   'sitting',
#   'sitting through',
#   'this',
#   'this one',
#   'through',
#   'through this',
#   'time',
#   'would',
#   'would have'],
#  ['would'],
#  ['hard',
#   'hard time',
#   'have',
#   'one',
#   'sitting',
#   'sitting through',
#   'this',
#   'this one',
#   'through',
#   'through this',
#   'time'],
#  ['have'],
#  ['hard',
#   'hard time',
#   'one',
#   'sitting',
#   'sitting through',
#   'this',
#   'this one',
#   'through',
#   'through this',
#   'time'],
#  ['hard', 'hard time', 'time'],
#  ['hard', 'hard time', 'time'],
#  ['hard'],
#  ['time'],
#  ['one',
#   'sitting',
#   'sitting through',
#   'this',
#   'this one',
#   'through',
#   'through this'],
#  ['sitting'],
#  ['one', 'this', 'this one', 'through', 'through this'],
#  ['through'],
#  ['one', 'this', 'this one'],
#  ['one'],
#  ['all',
#   'all the',
#   'and',
#   'and all',
#   'and murder',
#   'betrayal',
#   'combination',
#   'combination of',
#   'intrigue',
#   'juicy',
#   'murder',
#   'of',
#   'opera',
#   'or',
#   'positively',
#   'shakespearean',
#   'soap',
#   'soap opera',
#   'the',
#   'thrilling',
#   'tragedy'],
#  ['all',
#   'all the',
#   'and',
#   'and all',
#   'and murder',
#   'betrayal',
#   'combination',
#   'combination of',
#   'intrigue',
#   'juicy',
#   'murder',
#   'of',
#   'opera',
#   'or',
#   'positively',
#   'shakespearean',
#   'soap',
#   'soap opera',
#   'the',
#   'thrilling',
#   'tragedy'],
#  ['all',
#   'all the',
#   'and',
#   'and all',
#   'and murder',
#   'betrayal',
#   'combination',
#   'combination of',
#   'intrigue',
#   'murder',
#   'of',
#   'positively',
#   'the',
#   'thrilling'],
#  ['combination', 'positively', 'thrilling'],
#  ['combination', 'positively', 'thrilling'],
#  ['positively'],
#  ['combination', 'thrilling'],
#  ['thrilling'],
#  ['combination'],
#  ['all',
#   'all the',
#   'and',
#   'and all',
#   'and murder',
#   'betrayal',
#   'intrigue',
#   'murder',
#   'of',
#   'the'],
#  ['all',
#   'all the',
#   'and',
#   'and all',
#   'and murder',
#   'betrayal',
#   'intrigue',
#   'murder',
#   'the'],
#  ['and'],
#  [],
#  ['all',
#   'all the',
#   'and',
#   'and murder',
#   'betrayal',
#   'intrigue',
#   'murder',
#   'the'],
#  ['all'],
#  ['and', 'and murder', 'betrayal', 'intrigue', 'murder', 'the'],
#  ['and', 'and murder', 'betrayal', 'intrigue', 'murder'],
#  ['intrigue'],
#  ['and', 'and murder', 'betrayal', 'murder'],
#  ['and', 'and murder', 'betrayal', 'murder'],
#  ['betrayal'],
#  ['and', 'and murder', 'murder'],
#  ['and', 'and murder', 'murder'],
#  ['and'],
#  [],
#  ['murder'],
#  ['juicy',
#   'of',
#   'opera',
#   'or',
#   'shakespearean',
#   'soap',
#   'soap opera',
#   'tragedy'],
#  ['juicy', 'opera', 'or', 'shakespearean', 'soap', 'soap opera', 'tragedy'],
#  ['or', 'shakespearean', 'tragedy'],
#  ['shakespearean', 'tragedy'],
#  ['shakespearean', 'tragedy'],
#  ['shakespearean'],
#  ['tragedy'],
#  ['or'],
#  ['juicy', 'opera', 'soap', 'soap opera'],
#  ['juicy', 'opera', 'soap', 'soap opera'],
#  ['juicy'],
#  ['opera', 'soap', 'soap opera'],
#  ['soap'],
#  ['opera'],
#  ['aggressive', 'and', 'manipulative', 'self'],
#  ['aggressive', 'and', 'manipulative', 'self'],
#  ['aggressive'],
#  ['and', 'manipulative', 'self'],
#  ['and', 'self'],
#  ['self'],
#  ['manipulative'],
#  ['manipulative'],
#  ['manipulative'],
#  [],
#  ['by',
#   'by the',
#   'character',
#   'comedy',
#   'comedy drama',
#   'crisis',
#   'drama',
#   'epic',
#   'in',
#   'nearly',
#   'of',
#   'performance',
#   'performance by',
#   'proportions',
#   'sincere',
#   'the',
#   'the title',
#   'title',
#   'title character'],
#  ['comedy', 'comedy drama', 'drama', 'epic', 'nearly', 'of', 'proportions'],
#  ['comedy', 'comedy drama', 'drama'],
#  ['comedy', 'comedy drama', 'drama'],
#  ['epic', 'nearly', 'of', 'proportions'],
#  ['epic', 'nearly', 'proportions'],
#  ['epic', 'nearly'],
#  ['nearly'],
#  ['epic'],
#  ['proportions'],
#  ['by',
#   'by the',
#   'character',
#   'crisis',
#   'in',
#   'performance',
#   'performance by',
#   'sincere',
#   'the',
#   'the title',
#   'title',
#   'title character'],
#  ['by',
#   'by the',
#   'character',
#   'crisis',
#   'in',
#   'performance',
#   'performance by',
#   'sincere',
#   'the',
#   'the title',
#   'title',
#   'title character'],
#  ['in', 'performance', 'sincere'],
#  [],
#  ['in', 'performance', 'sincere'],
#  ['in'],
#  ['performance', 'sincere'],
#  ['performance', 'sincere'],
#  ['sincere'],
#  ['performance'],
#  ['by',
#   'by the',
#   'character',
#   'crisis',
#   'the',
#   'the title',
#   'title',
#   'title character'],
#  ['by'],
#  ['character', 'crisis', 'the', 'the title', 'title', 'title character'],
#  ['character', 'the', 'the title', 'title', 'title character'],
#  ['character', 'title', 'title character'],
#  ['title'],
#  ['character'],
#  ['crisis'],
#  [],
#  ['crisis'],
#  [],
#  ['crisis'],
#  ['day',
#   'day is',
#   'every',
#   'every day',
#   'is',
#   'mess',
#   'narratively',
#   'plodding',
#   'trouble',
#   'trouble every'],
#  ['narratively'],
#  ['day',
#   'day is',
#   'every',
#   'every day',
#   'is',
#   'mess',
#   'plodding',
#   'trouble',
#   'trouble every'],
#  ['day',
#   'day is',
#   'every',
#   'every day',
#   'is',
#   'mess',
#   'plodding',
#   'trouble',
#   'trouble every'],
#  ['day', 'every', 'every day', 'trouble', 'trouble every'],
#  ['trouble'],
#  ['day', 'every', 'every day'],
#  ['every'],
#  ['day'],
#  ['is', 'mess', 'plodding'],
#  ['is', 'mess', 'plodding'],
#  ['mess', 'plodding'],
#  ['mess', 'plodding'],
#  ['plodding'],
#  ['mess'],
#  ['bartlett',
#   'being',
#   'being earnest',
#   'earnest',
#   'familiar',
#   'from',
#   'importance',
#   'importance of',
#   'it',
#   'it plays',
#   'like',
#   'of',
#   'of being',
#   'plays',
#   'plays like',
#   'reading',
#   'so',
#   'the',
#   'the importance',
#   'thick',
#   'wit',
#   'with'],
#  ['importance', 'the', 'the importance'],
#  ['importance'],
#  ['bartlett',
#   'being',
#   'being earnest',
#   'earnest',
#   'familiar',
#   'from',
#   'it',
#   'it plays',
#   'like',
#   'of',
#   'of being',
#   'plays',
#   'plays like',
#   'reading',
#   'so',
#   'thick',
#   'wit',
#   'with'],
#  ['bartlett',
#   'being',
#   'being earnest',
#   'earnest',
#   'familiar',
#   'from',
#   'it',
#   'it plays',
#   'like',
#   'plays',
#   'plays like',
#   'reading',
#   'so',
#   'thick',
#   'wit',
#   'with'],
#  ['being'],
#  ['bartlett',
#   'earnest',
#   'familiar',
#   'from',
#   'it',
#   'it plays',
#   'like',
#   'plays',
#   'plays like',
#   'reading',
#   'so',
#   'thick',
#   'wit',
#   'with'],
#  ['earnest'],
#  ['earnest'],
#  ['bartlett',
#   'familiar',
#   'from',
#   'it',
#   'it plays',
#   'like',
#   'plays',
#   'plays like',
#   'reading',
#   'so',
#   'thick',
#   'wit',
#   'with'],
#  ['so'],
#  ['bartlett',
#   'familiar',
#   'from',
#   'it',
#   'it plays',
#   'like',
#   'plays',
#   'plays like',
#   'reading',
#   'thick',
#   'wit',
#   'with'],
#  ['thick'],
#  ['bartlett',
#   'familiar',
#   'from',
#   'it',
#   'it plays',
#   'like',
#   'plays',
#   'plays like',
#   'reading',
#   'wit',
#   'with'],
#  ['with'],
#  ['bartlett',
#   'familiar',
#   'from',
#   'it',
#   'it plays',
#   'like',
#   'plays',
#   'plays like',
#   'reading',
#   'wit'],
#  ['wit'],
#  ['bartlett',
#   'familiar',
#   'from',
#   'it',
#   'it plays',
#   'like',
#   'plays',
#   'plays like',
#   'reading'],
#  ['it'],
#  ['bartlett', 'familiar', 'from', 'like', 'plays', 'plays like', 'reading'],
#  ['plays'],
#  ['bartlett', 'familiar', 'from', 'like', 'reading'],
#  ['like'],
#  ['bartlett', 'familiar', 'from', 'reading'],
#  ['reading'],
#  ['reading'],
#  ['bartlett', 'familiar', 'from'],
#  ['from'],
#  ['bartlett', 'familiar'],
#  ['bartlett'],
#  ['bartlett'],
#  ['familiar'],
#  ['familiar'],
#  [],
#  ['but',
#   'but it',
#   'does',
#   'does not',
#   'it',
#   'it does',
#   'leave',
#   'leave you',
#   'much',
#   'not',
#   'with',
#   'you',
#   'you with'],
#  ['does',
#   'does not',
#   'it',
#   'it does',
#   'leave',
#   'leave you',
#   'much',
#   'not',
#   'with',
#   'you',
#   'you with'],
#  ['does',
#   'does not',
#   'leave',
#   'leave you',
#   'much',
#   'not',
#   'with',
#   'you',
#   'you with'],
#  ['does',
#   'does not',
#   'leave',
#   'leave you',
#   'much',
#   'not',
#   'with',
#   'you',
#   'you with'],
#  ['does'],
#  ['does'],
#  [],
#  ['leave', 'leave you', 'much', 'with', 'you', 'you with'],
#  ['leave', 'leave you', 'you'],
#  ['leave'],
#  ['you'],
#  ['much', 'with'],
#  ['could',
#   'for',
#   'for the',
#   'hate',
#   'hate it',
#   'it',
#   'it for',
#   'reason',
#   'same',
#   'the',
#   'the same',
#   'you',
#   'you could'],
#  ['could',
#   'for',
#   'for the',
#   'hate',
#   'hate it',
#   'it',
#   'it for',
#   'reason',
#   'same',
#   'the',
#   'the same'],
#  ['could',
#   'for',
#   'for the',
#   'hate',
#   'hate it',
#   'it',
#   'it for',
#   'reason',
#   'same',
#   'the',
#   'the same'],
#  ['could'],
#  ['for',
#   'for the',
#   'hate',
#   'hate it',
#   'it',
#   'it for',
#   'reason',
#   'same',
#   'the',
#   'the same'],
#  ['hate', 'hate it', 'it'],
#  ['hate'],
#  ['for', 'for the', 'reason', 'same', 'the', 'the same'],
#  ['reason', 'same', 'the', 'the same'],
#  ['reason', 'same'],
#  ['same'],
#  ['reason'],
#  ['and',
#   'cliched',
#   'dialogue',
#   'dialogue and',
#   'dogs',
#   'escapism',
#   'high',
#   'hilarity',
#   'little',
#   'little to',
#   'of',
#   'of high',
#   'one',
#   'perverse',
#   'recommend',
#   'snow',
#   'snow dogs',
#   'source',
#   'source of',
#   'there',
#   'to',
#   'to recommend',
#   'unless'],
#  ['there'],
#  ['and',
#   'cliched',
#   'dialogue',
#   'dialogue and',
#   'dogs',
#   'escapism',
#   'high',
#   'hilarity',
#   'little',
#   'little to',
#   'of',
#   'of high',
#   'one',
#   'perverse',
#   'recommend',
#   'snow',
#   'snow dogs',
#   'source',
#   'source of',
#   'to',
#   'to recommend',
#   'unless'],
#  ['and',
#   'cliched',
#   'dialogue',
#   'dialogue and',
#   'dogs',
#   'escapism',
#   'high',
#   'hilarity',
#   'little',
#   'little to',
#   'of',
#   'of high',
#   'one',
#   'perverse',
#   'recommend',
#   'snow',
#   'snow dogs',
#   'source',
#   'source of',
#   'to',
#   'to recommend',
#   'unless'],
#  ['dogs',
#   'little',
#   'little to',
#   'recommend',
#   'snow',
#   'snow dogs',
#   'to',
#   'to recommend'],
#  ['dogs',
#   'little',
#   'little to',
#   'recommend',
#   'snow',
#   'snow dogs',
#   'to',
#   'to recommend'],
#  ['dogs',
#   'little',
#   'little to',
#   'recommend',
#   'snow',
#   'snow dogs',
#   'to',
#   'to recommend'],
#  ['little'],
#  ['dogs', 'recommend', 'snow', 'snow dogs', 'to', 'to recommend'],
#  ['dogs', 'recommend', 'snow', 'snow dogs'],
#  ['recommend'],
#  ['dogs', 'snow', 'snow dogs'],
#  ['snow'],
#  ['dogs'],
#  ['and',
#   'cliched',
#   'dialogue',
#   'dialogue and',
#   'escapism',
#   'high',
#   'hilarity',
#   'of',
#   'of high',
#   'one',
#   'perverse',
#   'source',
#   'source of',
#   'unless'],
#  ['unless'],
#  ['and',
#   'cliched',
#   'dialogue',
#   'dialogue and',
#   'escapism',
#   'high',
#   'hilarity',
#   'of',
#   'of high',
#   'one',
#   'perverse',
#   'source',
#   'source of'],
#  ['and',
#   'cliched',
#   'dialogue',
#   'dialogue and',
#   'escapism',
#   'high',
#   'hilarity',
#   'of',
#   'of high',
#   'perverse',
#   'source',
#   'source of'],
#  [],
#  ['and',
#   'cliched',
#   'dialogue',
#   'dialogue and',
#   'escapism',
#   'high',
#   'hilarity',
#   'of',
#   'of high',
#   'perverse',
#   'source',
#   'source of'],
#  ['and', 'cliched', 'dialogue', 'dialogue and', 'escapism', 'perverse'],
#  ['and', 'cliched', 'dialogue', 'dialogue and'],
#  ['cliched', 'dialogue'],
#  ['cliched'],
#  ['dialogue'],
#  ['escapism', 'perverse'],
#  ['perverse'],
#  ['escapism'],
#  ['high', 'hilarity', 'of', 'of high', 'source', 'source of'],
#  ['source'],
#  ['source'],
#  ['high', 'hilarity', 'of', 'of high'],
#  ['high', 'hilarity'],
#  ['high'],
#  ['hilarity'],
#  ['and',
#   'arts',
#   'be',
#   'be in',
#   'childhood',
#   'dream',
#   'dreams',
#   'flick',
#   'his',
#   'in',
#   'is',
#   'just',
#   'just that',
#   'kung',
#   'kung pow',
#   'martial',
#   'martial arts',
#   'oedekerk',
#   'of',
#   'of his',
#   'of youth',
#   'pow',
#   'proves',
#   'proves that',
#   'remain',
#   'should',
#   'sometimes',
#   'that',
#   'the',
#   'to',
#   'to be',
#   'youth'],
#  ['kung', 'kung pow', 'pow'],
#  ['kung'],
#  ['pow'],
#  ['and',
#   'arts',
#   'be',
#   'be in',
#   'childhood',
#   'dream',
#   'dreams',
#   'flick',
#   'his',
#   'in',
#   'is',
#   'just',
#   'just that',
#   'martial',
#   'martial arts',
#   'oedekerk',
#   'of',
#   'of his',
#   'of youth',
#   'proves',
#   'proves that',
#   'remain',
#   'should',
#   'sometimes',
#   'that',
#   'the',
#   'to',
#   'to be',
#   'youth'],
#  ['and',
#   'arts',
#   'be',
#   'be in',
#   'childhood',
#   'dream',
#   'dreams',
#   'flick',
#   'his',
#   'in',
#   'is',
#   'just',
#   'just that',
#   'martial',
#   'martial arts',
#   'oedekerk',
#   'of',
#   'of his',
#   'of youth',
#   'proves',
#   'proves that',
#   'remain',
#   'should',
#   'sometimes',
#   'that',
#   'the',
#   'to',
#   'to be',
#   'youth'],
#  ['and',
#   'arts',
#   'be',
#   'be in',
#   'childhood',
#   'dream',
#   'flick',
#   'his',
#   'in',
#   'is',
#   'martial',
#   'martial arts',
#   'oedekerk',
#   'of',
#   'of his',
#   'to',
#   'to be'],
#  ['arts',
#   'be',
#   'be in',
#   'childhood',
#   'dream',
#   'flick',
#   'his',
#   'in',
#   'is',
#   'martial',
#   'martial arts',
#   'oedekerk',
#   'of',
#   'of his',
#   'to',
#   'to be'],
#  ['arts',
#   'be',
#   'be in',
#   'childhood',
#   'dream',
#   'flick',
#   'his',
#   'in',
#   'is',
#   'martial',
#   'martial arts',
#   'oedekerk',
#   'of',
#   'of his',
#   'to',
#   'to be'],
#  ['arts',
#   'be',
#   'be in',
#   'childhood',
#   'dream',
#   'flick',
#   'his',
#   'in',
#   'martial',
#   'martial arts',
#   'oedekerk',
#   'of',
#   'of his',
#   'to',
#   'to be'],
#  ['childhood', 'dream', 'his', 'oedekerk', 'of', 'of his'],
#  ['oedekerk'],
#  ['oedekerk'],
#  ['oedekerk'],
#  [],
#  ['childhood', 'dream', 'his', 'of', 'of his'],
#  ['childhood', 'dream', 'his'],
#  ['his'],
#  ['childhood', 'dream'],
#  ['childhood'],
#  ['dream'],
#  ['arts',
#   'be',
#   'be in',
#   'flick',
#   'in',
#   'martial',
#   'martial arts',
#   'to',
#   'to be'],
#  ['arts', 'be', 'be in', 'flick', 'in', 'martial', 'martial arts'],
#  ['be'],
#  ['arts', 'flick', 'in', 'martial', 'martial arts'],
#  ['arts', 'flick', 'martial', 'martial arts'],
#  ['arts', 'flick', 'martial', 'martial arts'],
#  ['arts', 'martial', 'martial arts'],
#  ['flick'],
#  ['dreams',
#   'just',
#   'just that',
#   'of',
#   'of youth',
#   'proves',
#   'proves that',
#   'remain',
#   'should',
#   'sometimes',
#   'that',
#   'the',
#   'youth'],
#  ['proves'],
#  ['dreams',
#   'just',
#   'just that',
#   'of',
#   'of youth',
#   'remain',
#   'should',
#   'sometimes',
#   'that',
#   'the',
#   'youth'],
#  ['dreams',
#   'just',
#   'just that',
#   'of',
#   'of youth',
#   'remain',
#   'should',
#   'sometimes',
#   'that',
#   'the',
#   'youth'],
#  ['sometimes'],
#  ['dreams',
#   'just',
#   'just that',
#   'of',
#   'of youth',
#   'remain',
#   'should',
#   'that',
#   'the',
#   'youth'],
#  ['dreams', 'of', 'of youth', 'the', 'youth'],
#  ['dreams', 'the'],
#  ['dreams'],
#  ['of', 'of youth', 'youth'],
#  ['youth'],
#  ['just', 'just that', 'remain', 'should', 'that'],
#  ['should'],
#  ['just', 'just that', 'remain', 'that'],
#  ['remain'],
#  ['just', 'just that', 'that'],
#  ['just'],
#  ['absolute',
#   'an',
#   'are',
#   'joy',
#   'performances',
#   'performances are',
#   'the',
#   'the performances'],
#  ['performances', 'the', 'the performances'],
#  ['performances'],
#  ['absolute', 'an', 'are', 'joy'],
#  ['absolute', 'an', 'are', 'joy'],
#  ['are'],
#  ['absolute', 'an', 'joy'],
#  ['an'],
#  ['absolute', 'joy'],
#  ['absolute'],
#  ['joy'],
#  ['about',
#   'about the',
#   'and',
#   'can',
#   'chance',
#   'extravagant',
#   'good',
#   'good sense',
#   'has',
#   'has something',
#   'in',
#   'in which',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'say',
#   'say about',
#   'sense',
#   'serious',
#   'something',
#   'the',
#   'the path',
#   'the ways',
#   'throw',
#   'to',
#   'to say',
#   'us',
#   'ways',
#   'ways in',
#   'which'],
#  [],
#  ['about',
#   'about the',
#   'and',
#   'can',
#   'chance',
#   'extravagant',
#   'good',
#   'good sense',
#   'has',
#   'has something',
#   'in',
#   'in which',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'say',
#   'say about',
#   'sense',
#   'serious',
#   'something',
#   'the',
#   'the path',
#   'the ways',
#   'throw',
#   'to',
#   'to say',
#   'us',
#   'ways',
#   'ways in',
#   'which'],
#  ['about',
#   'about the',
#   'and',
#   'can',
#   'chance',
#   'extravagant',
#   'good',
#   'good sense',
#   'has',
#   'has something',
#   'in',
#   'in which',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'say',
#   'say about',
#   'sense',
#   'serious',
#   'something',
#   'the',
#   'the path',
#   'the ways',
#   'throw',
#   'to',
#   'to say',
#   'us',
#   'ways',
#   'ways in',
#   'which'],
#  ['has'],
#  ['about',
#   'about the',
#   'and',
#   'can',
#   'chance',
#   'extravagant',
#   'good',
#   'good sense',
#   'in',
#   'in which',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'say',
#   'say about',
#   'sense',
#   'serious',
#   'something',
#   'the',
#   'the path',
#   'the ways',
#   'throw',
#   'to',
#   'to say',
#   'us',
#   'ways',
#   'ways in',
#   'which'],
#  ['something'],
#  ['about',
#   'about the',
#   'and',
#   'can',
#   'chance',
#   'extravagant',
#   'good',
#   'good sense',
#   'in',
#   'in which',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'say',
#   'say about',
#   'sense',
#   'serious',
#   'the',
#   'the path',
#   'the ways',
#   'throw',
#   'to',
#   'to say',
#   'us',
#   'ways',
#   'ways in',
#   'which'],
#  ['serious'],
#  ['about',
#   'about the',
#   'and',
#   'can',
#   'chance',
#   'extravagant',
#   'good',
#   'good sense',
#   'in',
#   'in which',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'say',
#   'say about',
#   'sense',
#   'the',
#   'the path',
#   'the ways',
#   'throw',
#   'to',
#   'to say',
#   'us',
#   'ways',
#   'ways in',
#   'which'],
#  ['about',
#   'about the',
#   'and',
#   'can',
#   'chance',
#   'extravagant',
#   'good',
#   'good sense',
#   'in',
#   'in which',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'say',
#   'say about',
#   'sense',
#   'the',
#   'the path',
#   'the ways',
#   'throw',
#   'us',
#   'ways',
#   'ways in',
#   'which'],
#  ['say'],
#  ['about',
#   'about the',
#   'and',
#   'can',
#   'chance',
#   'extravagant',
#   'good',
#   'good sense',
#   'in',
#   'in which',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'sense',
#   'the',
#   'the path',
#   'the ways',
#   'throw',
#   'us',
#   'ways',
#   'ways in',
#   'which'],
#  ['about'],
#  ['and',
#   'can',
#   'chance',
#   'extravagant',
#   'good',
#   'good sense',
#   'in',
#   'in which',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'sense',
#   'the',
#   'the path',
#   'the ways',
#   'throw',
#   'us',
#   'ways',
#   'ways in',
#   'which'],
#  ['the', 'the ways', 'ways'],
#  ['ways'],
#  ['and',
#   'can',
#   'chance',
#   'extravagant',
#   'good',
#   'good sense',
#   'in',
#   'in which',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'sense',
#   'the',
#   'the path',
#   'throw',
#   'us',
#   'which'],
#  ['in', 'in which', 'which'],
#  ['and',
#   'can',
#   'chance',
#   'extravagant',
#   'good',
#   'good sense',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'sense',
#   'the',
#   'the path',
#   'throw',
#   'us'],
#  ['chance', 'extravagant'],
#  ['extravagant'],
#  ['chance'],
#  ['and',
#   'can',
#   'good',
#   'good sense',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'sense',
#   'the',
#   'the path',
#   'throw',
#   'us'],
#  ['can'],
#  ['and',
#   'good',
#   'good sense',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'our',
#   'path',
#   'path of',
#   'perspective',
#   'sense',
#   'the',
#   'the path',
#   'throw',
#   'us'],
#  ['and', 'our', 'perspective'],
#  ['our', 'perspective'],
#  [],
#  ['our', 'perspective'],
#  ['our'],
#  ['perspective'],
#  ['good',
#   'good sense',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'path',
#   'path of',
#   'sense',
#   'the',
#   'the path',
#   'throw',
#   'us'],
#  ['throw', 'us'],
#  ['throw'],
#  ['us'],
#  ['good',
#   'good sense',
#   'of',
#   'of good',
#   'off',
#   'off the',
#   'path',
#   'path of',
#   'sense',
#   'the',
#   'the path'],
#  ['off'],
#  ['good',
#   'good sense',
#   'of',
#   'of good',
#   'path',
#   'path of',
#   'sense',
#   'the',
#   'the path'],
#  ['path', 'the', 'the path'],
#  ['path'],
#  ['good', 'good sense', 'of', 'of good', 'sense'],
#  ['good', 'good sense', 'sense'],
#  ['sense'],
#  ['be', 'better', 'damned', 'like', 'mile', 'still'],
#  ['be', 'better', 'damned', 'like', 'mile', 'still'],
#  ['still'],
#  ['be', 'better', 'damned', 'like', 'mile'],
#  ['be', 'better', 'damned', 'like', 'mile'],
#  ['be', 'better', 'damned', 'mile'],
#  ['better', 'mile'],
#  [],
#  ['better', 'mile'],
#  ['mile'],
#  ['better'],
#  ['better'],
#  ['better'],
#  [],
#  ['be', 'damned'],
#  ['damned'],
#  ['and',
#   'and ultimately',
#   'be',
#   'from',
#   'hard',
#   'hard to',
#   'is',
#   'is sweet',
#   'modest',
#   'movies',
#   'movies that',
#   'mythic',
#   'one',
#   'one is',
#   'relief',
#   'story',
#   'sweet',
#   'sweet and',
#   'that',
#   'this',
#   'this one',
#   'to',
#   'to be',
#   'too',
#   'too hard',
#   'try',
#   'ultimately',
#   'welcome',
#   'winning'],
#  ['be',
#   'from',
#   'hard',
#   'hard to',
#   'movies',
#   'movies that',
#   'mythic',
#   'relief',
#   'that',
#   'to',
#   'to be',
#   'too',
#   'too hard',
#   'try',
#   'welcome'],
#  ['relief', 'welcome'],
#  ['relief', 'welcome'],
#  ['welcome'],
#  ['relief'],
#  ['be',
#   'from',
#   'hard',
#   'hard to',
#   'movies',
#   'movies that',
#   'mythic',
#   'that',
#   'to',
#   'to be',
#   'too',
#   'too hard',
#   'try'],
#  ['be',
#   'hard',
#   'hard to',
#   'movies',
#   'movies that',
#   'mythic',
#   'that',
#   'to',
#   'to be',
#   'too',
#   'too hard',
#   'try'],
#  ['movies'],
#  [],
#  ['movies'],
#  ['be',
#   'hard',
#   'hard to',
#   'mythic',
#   'that',
#   'to',
#   'to be',
#   'too',
#   'too hard',
#   'try'],
#  ['be', 'hard', 'hard to', 'mythic', 'to', 'to be', 'too', 'too hard', 'try'],
#  ['try'],
#  ['be', 'hard', 'hard to', 'mythic', 'to', 'to be', 'too', 'too hard'],
#  ['too'],
#  ['be', 'hard', 'hard to', 'mythic', 'to', 'to be'],
#  ['be', 'mythic', 'to', 'to be'],
#  ['be', 'mythic'],
#  ['mythic'],
#  ['and',
#   'and ultimately',
#   'is',
#   'is sweet',
#   'modest',
#   'one',
#   'one is',
#   'story',
#   'sweet',
#   'sweet and',
#   'this',
#   'this one',
#   'ultimately',
#   'winning'],
#  ['and',
#   'and ultimately',
#   'is',
#   'is sweet',
#   'modest',
#   'one',
#   'one is',
#   'story',
#   'sweet',
#   'sweet and',
#   'this',
#   'this one',
#   'ultimately',
#   'winning'],
#  ['and',
#   'and ultimately',
#   'is',
#   'is sweet',
#   'modest',
#   'story',
#   'sweet',
#   'sweet and',
#   'ultimately',
#   'winning'],
#  ['and',
#   'and ultimately',
#   'is',
#   'is sweet',
#   'modest',
#   'story',
#   'sweet',
#   'sweet and',
#   'ultimately',
#   'winning'],
#  ['and',
#   'and ultimately',
#   'modest',
#   'story',
#   'sweet',
#   'sweet and',
#   'ultimately',
#   'winning'],
#  ['and', 'modest', 'sweet', 'sweet and'],
#  ['and', 'modest', 'sweet', 'sweet and'],
#  ['and', 'modest', 'sweet', 'sweet and'],
#  ['and', 'sweet', 'sweet and'],
#  ['sweet'],
#  ['modest'],
#  ['story', 'ultimately', 'winning'],
#  ['ultimately'],
#  ['story', 'winning'],
#  ['winning'],
#  ['charmer',
#   'inspired',
#   'it',
#   'just',
#   'just like',
#   'like',
#   'like the',
#   'the',
#   'who',
#   'woman',
#   'woman who'],
#  ['charmer'],
#  ['charmer'],
#  ['charmer'],
#  [],
#  ['charmer'],
#  ['inspired',
#   'it',
#   'just',
#   'just like',
#   'like',
#   'like the',
#   'the',
#   'who',
#   'woman',
#   'woman who'],
#  ['inspired', 'it', 'like', 'like the', 'the', 'who', 'woman', 'woman who'],
#  ['inspired', 'it', 'the', 'who', 'woman', 'woman who'],
#  ['the', 'woman'],
#  ['woman'],
#  ['inspired', 'it', 'who'],
#  ['who'],
#  ['inspired', 'it'],
#  ['inspired'],
#  ['despite',
#   'despite its',
#   'for',
#   'gorgeous',
#   'hong',
#   'hong kong',
#   'in',
#   'in the',
#   'its',
#   'kong',
#   'less',
#   'like',
#   'love',
#   'mood',
#   'mood for',
#   'movie',
#   'mr',
#   'much',
#   'setting',
#   'the',
#   'the mood',
#   'to',
#   'very',
#   'very much'],
#  ['gorgeous', 'less', 'like', 'mr', 'to'],
#  ['gorgeous', 'less', 'mr', 'to'],
#  ['gorgeous', 'less'],
#  ['gorgeous', 'less'],
#  ['gorgeous', 'less'],
#  ['less'],
#  ['gorgeous'],
#  [],
#  ['gorgeous'],
#  [],
#  ['mr', 'to'],
#  ['mr'],
#  ['despite',
#   'despite its',
#   'for',
#   'hong',
#   'hong kong',
#   'in',
#   'in the',
#   'its',
#   'kong',
#   'love',
#   'mood',
#   'mood for',
#   'movie',
#   'much',
#   'setting',
#   'the',
#   'the mood',
#   'very',
#   'very much'],
#  [],
#  ['despite',
#   'despite its',
#   'for',
#   'hong',
#   'hong kong',
#   'in',
#   'in the',
#   'its',
#   'kong',
#   'love',
#   'mood',
#   'mood for',
#   'movie',
#   'much',
#   'setting',
#   'the',
#   'the mood',
#   'very',
#   'very much'],
#  ['despite',
#   'despite its',
#   'for',
#   'hong',
#   'hong kong',
#   'in',
#   'in the',
#   'its',
#   'kong',
#   'love',
#   'mood',
#   'mood for',
#   'movie',
#   'much',
#   'setting',
#   'the',
#   'the mood',
#   'very',
#   'very much'],
#  ['for',
#   'hong',
#   'hong kong',
#   'in',
#   'in the',
#   'kong',
#   'love',
#   'mood',
#   'mood for',
#   'movie',
#   'much',
#   'the',
#   'the mood',
#   'very',
#   'very much'],
#  ['for',
#   'hong',
#   'hong kong',
#   'in',
#   'in the',
#   'kong',
#   'love',
#   'mood',
#   'mood for',
#   'movie',
#   'much',
#   'the',
#   'the mood',
#   'very',
#   'very much'],
#  ['for',
#   'hong',
#   'hong kong',
#   'kong',
#   'love',
#   'mood',
#   'mood for',
#   'movie',
#   'much',
#   'the',
#   'the mood',
#   'very',
#   'very much'],
#  ['mood', 'the', 'the mood'],
#  ['mood'],
#  ['for',
#   'hong',
#   'hong kong',
#   'kong',
#   'love',
#   'movie',
#   'much',
#   'very',
#   'very much'],
#  ['hong', 'hong kong', 'kong', 'love', 'movie', 'much', 'very', 'very much'],
#  ['love', 'much', 'very', 'very much'],
#  ['love'],
#  ['love'],
#  [],
#  ['much', 'very', 'very much'],
#  ['very'],
#  ['hong', 'hong kong', 'kong', 'movie'],
#  ['hong', 'hong kong', 'kong', 'movie'],
#  ['hong'],
#  ['kong', 'movie'],
#  ['kong'],
#  ['movie'],
#  ['despite', 'despite its', 'its', 'setting'],
#  ['despite'],
#  ['its', 'setting'],
#  ['its'],
#  ['setting'],
#  [],
#  ['setting'],
#  ['and',
#   'and the',
#   'as',
#   'big',
#   'big screen',
#   'inept',
#   'of',
#   'of the',
#   'screen',
#   'the',
#   'the wild',
#   'west',
#   'wild'],
#  ['and',
#   'and the',
#   'as',
#   'big',
#   'big screen',
#   'inept',
#   'of',
#   'of the',
#   'screen',
#   'the',
#   'the wild',
#   'west',
#   'wild'],
#  ['as', 'inept'],
#  ['as'],
#  ['inept'],
#  ['and',
#   'and the',
#   'as',
#   'big',
#   'big screen',
#   'of',
#   'of the',
#   'screen',
#   'the',
#   'the wild',
#   'west',
#   'wild'],
#  ['and',
#   'and the',
#   'big',
#   'big screen',
#   'of',
#   'of the',
#   'screen',
#   'the',
#   'the wild',
#   'west',
#   'wild'],
#  ['big', 'big screen', 'screen'],
#  ['big', 'big screen', 'screen'],
#  [],
#  ['and', 'and the', 'of', 'of the', 'the', 'the wild', 'west', 'wild'],
#  ['and', 'and the', 'the', 'the wild', 'west', 'wild'],
#  ['and', 'the'],
#  ['the'],
#  [],
#  ['the', 'the wild', 'west', 'wild'],
#  ['west', 'wild'],
#  ['wild'],
#  ['west', 'wild'],
#  ['west'],
#  ['but',
#   'but nothing',
#   'everything',
#   'expect',
#   'it',
#   'more',
#   'nothing',
#   'nothing more',
#   'you',
#   'you expect'],
#  ['but',
#   'but nothing',
#   'everything',
#   'expect',
#   'more',
#   'nothing',
#   'nothing more',
#   'you',
#   'you expect'],
#  ['but',
#   'but nothing',
#   'everything',
#   'expect',
#   'more',
#   'nothing',
#   'nothing more',
#   'you',
#   'you expect'],
#  ['but',
#   'but nothing',
#   'everything',
#   'expect',
#   'more',
#   'nothing',
#   'nothing more',
#   'you',
#   'you expect'],
#  ['everything'],
#  ['but',
#   'but nothing',
#   'expect',
#   'more',
#   'nothing',
#   'nothing more',
#   'you',
#   'you expect'],
#  ['but', 'but nothing', 'expect', 'more', 'nothing', 'nothing more'],
#  [],
#  ['but', 'but nothing', 'expect', 'more', 'nothing', 'nothing more'],
#  ['but', 'but nothing', 'expect', 'nothing'],
#  ['expect'],
#  ['expect'],
#  ['but', 'but nothing', 'nothing'],
#  ['nothing'],
#  ['more'],
#  ['best',
#   'far',
#   'indie',
#   'of',
#   'of the',
#   'so',
#   'so far',
#   'the',
#   'the year',
#   'year'],
#  ['best'],
#  ['far', 'indie', 'of', 'of the', 'so', 'so far', 'the', 'the year', 'year'],
#  ['far', 'indie', 'of', 'of the', 'so', 'so far', 'the', 'the year', 'year'],
#  ['indie', 'of', 'of the', 'the', 'the year', 'year'],
#  ['indie', 'of', 'of the', 'the', 'the year', 'year'],
#  ['indie'],
#  ['of', 'of the', 'the', 'the year', 'year'],
#  ['the', 'the year', 'year'],
#  ['year'],
#  ['far', 'so', 'so far'],
#  ['far'],
#  ['all',
#   'all the',
#   'and',
#   'and in',
#   'apart',
#   'apart from',
#   'becomes',
#   'case',
#   'exists',
#   'from',
#   'in',
#   'in this',
#   'make',
#   'make the',
#   'movie',
#   'oddest',
#   'of',
#   'of the',
#   'offering',
#   'political',
#   'sense',
#   'study',
#   'study of',
#   'that',
#   'the',
#   'the movie',
#   'this',
#   'world'],
#  ['all',
#   'all the',
#   'and',
#   'and in',
#   'apart',
#   'apart from',
#   'becomes',
#   'case',
#   'exists',
#   'from',
#   'in',
#   'in this',
#   'make',
#   'make the',
#   'movie',
#   'oddest',
#   'of',
#   'of the',
#   'offering',
#   'political',
#   'sense',
#   'study',
#   'study of',
#   'that',
#   'the',
#   'the movie',
#   'this',
#   'world'],
#  ['and', 'make', 'make the', 'oddest', 'of', 'the'],
#  ['and', 'make', 'make the', 'oddest', 'of', 'the'],
#  ['and', 'make', 'make the', 'oddest', 'of', 'the'],
#  ['and'],
#  ['and'],
#  [],
#  [],
#  ['make', 'make the', 'oddest', 'of', 'the'],
#  ['make'],
#  ['oddest', 'of', 'the'],
#  ['oddest', 'the'],
#  ['oddest'],
#  ['of'],
#  [],
#  ['all',
#   'all the',
#   'apart',
#   'apart from',
#   'becomes',
#   'case',
#   'exists',
#   'from',
#   'in',
#   'in this',
#   'movie',
#   'of',
#   'of the',
#   'offering',
#   'political',
#   'sense',
#   'study',
#   'study of',
#   'that',
#   'the',
#   'the movie',
#   'this',
#   'world'],
#  ['in', 'in this', 'sense', 'this'],
#  ['sense', 'this'],
#  ['all',
#   'all the',
#   'apart',
#   'apart from',
#   'becomes',
#   'case',
#   'exists',
#   'from',
#   'movie',
#   'of',
#   'of the',
#   'offering',
#   'political',
#   'study',
#   'study of',
#   'that',
#   'the',
#   'the movie',
#   'world'],
#  ['movie', 'the', 'the movie'],
#  ['all',
#   'all the',
#   'apart',
#   'apart from',
#   'becomes',
#   'case',
#   'exists',
#   'from',
#   'movie',
#   'of',
#   'of the',
#   'offering',
#   'political',
#   'study',
#   'study of',
#   'that',
#   'the',
#   'the movie',
#   'world'],
#  ['becomes', 'of', 'of the', 'study', 'study of', 'the', 'world'],
#  ['becomes', 'of', 'of the', 'study', 'study of', 'the', 'world'],
#  ['becomes'],
#  ['of', 'of the', 'study', 'study of', 'the', 'world'],
#  ['study'],
#  ['study'],
#  ['of', 'of the', 'the', 'world'],
#  ['of', 'of the', 'the', 'world'],
#  ['the'],
#  [],
#  ['of', 'of the', 'the', 'world'],
#  ['the', 'world'],
#  ['world'],
#  [],
#  ['world'],
#  ['all',
#   'all the',
#   'apart',
#   'apart from',
#   'case',
#   'exists',
#   'from',
#   'movie',
#   'offering',
#   'political',
#   'study',
#   'that',
#   'the',
#   'the movie'],
#  ['offering'],
#  ['all',
#   'all the',
#   'apart',
#   'apart from',
#   'case',
#   'exists',
#   'from',
#   'movie',
#   'political',
#   'study',
#   'that',
#   'the',
#   'the movie'],
#  ['case', 'study'],
#  ['case', 'study'],
#  ['case'],
#  ['all',
#   'all the',
#   'apart',
#   'apart from',
#   'exists',
#   'from',
#   'movie',
#   'political',
#   'that',
#   'the',
#   'the movie'],
#  ['all',
#   'all the',
#   'apart',
#   'apart from',
#   'exists',
#   'from',
#   'movie',
#   'political',
#   'the',
#   'the movie'],
#  ['apart', 'exists'],
#  ['exists'],
#  ['apart'],
#  ['all', 'all the', 'from', 'movie', 'political', 'the', 'the movie'],
#  ['all', 'all the', 'movie', 'political', 'the', 'the movie'],
#  ['movie', 'political', 'the', 'the movie'],
#  ['movie', 'the', 'the movie'],
#  ['movie'],
#  ['political'],
#  ['political'],
#  [],
#  ['against',
#   'and',
#   'girlfriend',
#   'going',
#   'going to',
#   'himself',
#   'host',
#   'house',
#   'it',
#   'it like',
#   'like',
#   'party',
#   'the',
#   'to',
#   'watching',
#   'watching the'],
#  ['against',
#   'and',
#   'girlfriend',
#   'going',
#   'going to',
#   'himself',
#   'host',
#   'house',
#   'like',
#   'party',
#   'the',
#   'to',
#   'watching',
#   'watching the'],
#  ['against',
#   'and',
#   'girlfriend',
#   'going',
#   'going to',
#   'himself',
#   'host',
#   'house',
#   'like',
#   'party',
#   'the',
#   'to',
#   'watching',
#   'watching the'],
#  ['against',
#   'and',
#   'girlfriend',
#   'going',
#   'going to',
#   'himself',
#   'host',
#   'house',
#   'like',
#   'party',
#   'the',
#   'to',
#   'watching',
#   'watching the'],
#  ['against',
#   'and',
#   'girlfriend',
#   'going',
#   'going to',
#   'himself',
#   'host',
#   'house',
#   'party',
#   'the',
#   'to',
#   'watching',
#   'watching the'],
#  ['and', 'going', 'going to', 'house', 'party', 'to'],
#  ['going', 'going to', 'house', 'party', 'to'],
#  ['going'],
#  ['house', 'party', 'to'],
#  ['house', 'party'],
#  ['house', 'party'],
#  ['house'],
#  ['party'],
#  ['against',
#   'girlfriend',
#   'himself',
#   'host',
#   'the',
#   'watching',
#   'watching the'],
#  ['watching'],
#  ['against', 'girlfriend', 'himself', 'host', 'the'],
#  ['host', 'the'],
#  ['host'],
#  ['against', 'girlfriend', 'himself'],
#  ['himself'],
#  [],
#  ['himself'],
#  ['against', 'girlfriend'],
#  ['against'],
#  ['girlfriend'],
#  ['girlfriend'],
#  [],
#  ['girlfriend'],
#  ['about',
#   'during',
#   'film',
#   'film is',
#   'gag',
#   'good',
#   'how',
#   'indication',
#   'is',
#   'is good',
#   'minded',
#   'of',
#   'of how',
#   'serious',
#   'serious minded',
#   'that',
#   'that the',
#   'the',
#   'the film',
#   'times',
#   'windtalkers'],
#  ['gag', 'that', 'that the', 'the'],
#  ['gag', 'the'],
#  ['gag'],
#  [],
#  ['gag'],
#  [],
#  ['gag'],
#  [],
#  ['gag'],
#  [],
#  ['gag'],
#  ['gag'],
#  [],
#  ['about',
#   'during',
#   'film',
#   'film is',
#   'good',
#   'how',
#   'indication',
#   'is',
#   'is good',
#   'minded',
#   'of',
#   'of how',
#   'serious',
#   'serious minded',
#   'the',
#   'the film',
#   'times',
#   'windtalkers'],
#  ['about',
#   'during',
#   'film',
#   'film is',
#   'good',
#   'how',
#   'indication',
#   'is',
#   'is good',
#   'minded',
#   'of',
#   'of how',
#   'serious',
#   'serious minded',
#   'the',
#   'the film',
#   'times',
#   'windtalkers'],
#  [],
#  ['about',
#   'during',
#   'film',
#   'film is',
#   'good',
#   'how',
#   'indication',
#   'is',
#   'is good',
#   'minded',
#   'of',
#   'of how',
#   'serious',
#   'serious minded',
#   'the',
#   'the film',
#   'times',
#   'windtalkers'],
#  ['about', 'during', 'times', 'windtalkers'],
#  ['about', 'times'],
#  ['times'],
#  [],
#  ['times'],
#  ['during', 'windtalkers'],
#  ['during'],
#  ['windtalkers'],
#  ['film',
#   'film is',
#   'good',
#   'how',
#   'indication',
#   'is',
#   'is good',
#   'minded',
#   'of',
#   'of how',
#   'serious',
#   'serious minded',
#   'the',
#   'the film'],
#  ['film',
#   'film is',
#   'good',
#   'how',
#   'indication',
#   'is',
#   'minded',
#   'of',
#   'of how',
#   'serious',
#   'serious minded',
#   'the',
#   'the film'],
#  ['good', 'indication'],
#  ['good', 'indication'],
#  ['indication'],
#  ['film',
#   'film is',
#   'how',
#   'is',
#   'minded',
#   'of',
#   'of how',
#   'serious',
#   'serious minded',
#   'the',
#   'the film'],
#  ['film',
#   'film is',
#   'how',
#   'is',
#   'minded',
#   'serious',
#   'serious minded',
#   'the',
#   'the film'],
#  ['how'],
#  ['film',
#   'film is',
#   'is',
#   'minded',
#   'serious',
#   'serious minded',
#   'the',
#   'the film'],
#  ['film', 'minded', 'serious', 'serious minded', 'the', 'the film'],
#  ['minded', 'serious', 'serious minded'],
#  ['film', 'the', 'the film'],
#  ['film'],
#  ['comedy',
#   'finish',
#   'from',
#   'from start',
#   'is',
#   'plot',
#   'plot is',
#   'romantic',
#   'romantic comedy',
#   'start',
#   'start to',
#   'the',
#   'the plot',
#   'to',
#   'to finish'],
#  ['plot', 'the', 'the plot'],
#  ['plot'],
#  ['comedy',
#   'finish',
#   'from',
#   'from start',
#   'is',
#   'romantic',
#   'romantic comedy',
#   'start',
#   'start to',
#   'to',
#   'to finish'],
#  ['comedy',
#   'finish',
#   'from',
#   'from start',
#   'is',
#   'romantic',
#   'romantic comedy',
#   'start',
#   'start to',
#   'to',
#   'to finish'],
#  ['comedy',
#   'finish',
#   'from',
#   'from start',
#   'romantic',
#   'romantic comedy',
#   'start',
#   'start to',
#   'to',
#   'to finish'],
#  ['comedy', 'from', 'from start', 'romantic', 'romantic comedy', 'start'],
#  ['comedy', 'romantic', 'romantic comedy'],
#  ['romantic'],
#  ['comedy'],
#  ['comedy'],
#  [],
#  ['from', 'from start', 'start'],
#  ['start'],
#  ['finish', 'to', 'to finish'],
#  ['finish'],
#  ['almost',
#   'an',
#   'and',
#   'and almost',
#   'arrives',
#   'complications',
#   'impeccable',
#   'it',
#   'pedigree',
#   'plot',
#   'with',
#   'with an'],
#  ['almost',
#   'an',
#   'and',
#   'and almost',
#   'arrives',
#   'complications',
#   'impeccable',
#   'pedigree',
#   'plot',
#   'with',
#   'with an'],
#  ['almost',
#   'an',
#   'and',
#   'and almost',
#   'arrives',
#   'complications',
#   'impeccable',
#   'pedigree',
#   'plot',
#   'with',
#   'with an'],
#  ['arrives'],
#  ['almost',
#   'an',
#   'and',
#   'and almost',
#   'complications',
#   'impeccable',
#   'pedigree',
#   'plot',
#   'with',
#   'with an'],
#  ['almost',
#   'an',
#   'and',
#   'and almost',
#   'complications',
#   'impeccable',
#   'pedigree',
#   'plot'],
#  ['almost', 'an', 'and', 'and almost', 'impeccable', 'pedigree'],
#  ['an', 'and', 'impeccable', 'pedigree'],
#  ['an', 'impeccable', 'pedigree'],
#  ['an', 'impeccable', 'pedigree'],
#  ['impeccable', 'pedigree'],
#  ['impeccable'],
#  ['pedigree'],
#  ['pedigree'],
#  [],
#  [],
#  [],
#  [],
#  ['almost'],
#  ['complications', 'plot'],
#  [],
#  ['complications', 'plot'],
#  ['complications'],
#  ['clearly', 'film', 'film that', 'means', 'that', 'the', 'to', 'to the'],
#  ['clearly', 'film', 'film that', 'means', 'that', 'to'],
#  ['film'],
#  ['clearly', 'means', 'that', 'to'],
#  ['clearly', 'means', 'to'],
#  ['clearly'],
#  ['means', 'to'],
#  ['means'],
#  ['the', 'to', 'to the'],
#  ['the', 'to', 'to the'],
#  [],
#  [],
#  [],
#  ['the', 'to', 'to the'],
#  ['the'],
#  [],
#  ['actors',
#   'and',
#   'and the',
#   'be',
#   'be in',
#   'being',
#   'being earnest',
#   'beyond',
#   'chuckles',
#   'does',
#   'does not',
#   'earnest',
#   'for',
#   'give',
#   'importance',
#   'importance of',
#   'in',
#   'in the',
#   'it',
#   'it does',
#   'not',
#   'not give',
#   'occasional',
#   'of',
#   'of being',
#   'offers',
#   'opportunities',
#   'performances',
#   'reason',
#   'reason to',
#   'smiles',
#   'smiles and',
#   'the',
#   'the actors',
#   'the importance',
#   'the theater',
#   'theater',
#   'to',
#   'to be',
#   'us',
#   'while',
#   'while the',
#   'wilde',
#   'wit',
#   'wit and'],
#  ['and',
#   'being',
#   'being earnest',
#   'chuckles',
#   'earnest',
#   'for',
#   'importance',
#   'importance of',
#   'occasional',
#   'of',
#   'of being',
#   'offers',
#   'opportunities',
#   'smiles',
#   'smiles and',
#   'the',
#   'the importance',
#   'while',
#   'while the'],
#  ['while'],
#  ['and',
#   'being',
#   'being earnest',
#   'chuckles',
#   'earnest',
#   'for',
#   'importance',
#   'importance of',
#   'occasional',
#   'of',
#   'of being',
#   'offers',
#   'opportunities',
#   'smiles',
#   'smiles and',
#   'the',
#   'the importance'],
#  ['being',
#   'being earnest',
#   'earnest',
#   'importance',
#   'importance of',
#   'of',
#   'of being',
#   'the',
#   'the importance'],
#  ['being', 'being earnest', 'earnest', 'of', 'of being'],
#  ['being', 'being earnest', 'earnest'],
#  ['and',
#   'chuckles',
#   'for',
#   'occasional',
#   'offers',
#   'opportunities',
#   'smiles',
#   'smiles and'],
#  ['and',
#   'for',
#   'occasional',
#   'offers',
#   'opportunities',
#   'smiles',
#   'smiles and'],
#  ['for', 'occasional', 'offers', 'opportunities', 'smiles'],
#  ['offers'],
#  ['for', 'occasional', 'opportunities', 'smiles'],
#  ['opportunities'],
#  ['for', 'occasional', 'smiles'],
#  ['occasional', 'smiles'],
#  ['occasional'],
#  ['smiles'],
#  ['chuckles'],
#  ['actors',
#   'and',
#   'and the',
#   'be',
#   'be in',
#   'beyond',
#   'does',
#   'does not',
#   'give',
#   'in',
#   'in the',
#   'it',
#   'it does',
#   'not',
#   'not give',
#   'performances',
#   'reason',
#   'reason to',
#   'the',
#   'the actors',
#   'the theater',
#   'theater',
#   'to',
#   'to be',
#   'us',
#   'wilde',
#   'wit',
#   'wit and'],
#  ['actors',
#   'and',
#   'and the',
#   'be',
#   'be in',
#   'beyond',
#   'does',
#   'does not',
#   'give',
#   'in',
#   'in the',
#   'it',
#   'it does',
#   'not',
#   'not give',
#   'performances',
#   'reason',
#   'reason to',
#   'the',
#   'the actors',
#   'the theater',
#   'theater',
#   'to',
#   'to be',
#   'us',
#   'wilde',
#   'wit',
#   'wit and'],
#  ['actors',
#   'and',
#   'and the',
#   'be',
#   'be in',
#   'beyond',
#   'does',
#   'does not',
#   'give',
#   'in',
#   'in the',
#   'not',
#   'not give',
#   'performances',
#   'reason',
#   'reason to',
#   'the',
#   'the actors',
#   'the theater',
#   'theater',
#   'to',
#   'to be',
#   'us',
#   'wilde',
#   'wit',
#   'wit and'],
#  ['actors',
#   'and',
#   'and the',
#   'be',
#   'be in',
#   'beyond',
#   'does',
#   'does not',
#   'give',
#   'in',
#   'in the',
#   'not',
#   'not give',
#   'performances',
#   'reason',
#   'reason to',
#   'the',
#   'the actors',
#   'the theater',
#   'theater',
#   'to',
#   'to be',
#   'us',
#   'wilde',
#   'wit',
#   'wit and'],
#  ['actors',
#   'and',
#   'and the',
#   'be',
#   'be in',
#   'beyond',
#   'give',
#   'in',
#   'in the',
#   'performances',
#   'reason',
#   'reason to',
#   'the',
#   'the actors',
#   'the theater',
#   'theater',
#   'to',
#   'to be',
#   'us',
#   'wilde',
#   'wit',
#   'wit and'],
#  ['give', 'us'],
#  ['give'],
#  ['actors',
#   'and',
#   'and the',
#   'be',
#   'be in',
#   'beyond',
#   'in',
#   'in the',
#   'performances',
#   'reason',
#   'reason to',
#   'the',
#   'the actors',
#   'the theater',
#   'theater',
#   'to',
#   'to be',
#   'wilde',
#   'wit',
#   'wit and'],
#  ['actors',
#   'and',
#   'and the',
#   'be',
#   'be in',
#   'beyond',
#   'in',
#   'in the',
#   'performances',
#   'reason',
#   'reason to',
#   'the',
#   'the actors',
#   'the theater',
#   'theater',
#   'to',
#   'to be',
#   'wilde',
#   'wit',
#   'wit and'],
#  ['actors',
#   'and',
#   'and the',
#   'be',
#   'be in',
#   'beyond',
#   'in',
#   'in the',
#   'performances',
#   'the',
#   'the actors',
#   'the theater',
#   'theater',
#   'to',
#   'to be',
#   'wilde',
#   'wit',
#   'wit and'],
#  ['actors',
#   'and',
#   'and the',
#   'be',
#   'be in',
#   'beyond',
#   'in',
#   'in the',
#   'performances',
#   'the',
#   'the actors',
#   'the theater',
#   'theater',
#   'wilde',
#   'wit',
#   'wit and'],
#  ['be', 'be in', 'in', 'in the', 'the', 'the theater', 'theater'],
#  ['in', 'in the', 'the', 'the theater', 'theater'],
#  ['the', 'the theater', 'theater'],
#  ['theater'],
#  ['actors',
#   'and',
#   'and the',
#   'beyond',
#   'performances',
#   'the',
#   'the actors',
#   'wilde',
#   'wit',
#   'wit and'],
#  ['beyond'],
#  ['actors',
#   'and',
#   'and the',
#   'performances',
#   'the',
#   'the actors',
#   'wilde',
#   'wit',
#   'wit and'],
#  ['and', 'wilde', 'wit', 'wit and'],
#  ['wilde', 'wit'],
#  ['wilde'],
#  ['wilde'],
#  ['actors', 'performances', 'the', 'the actors'],
#  ['actors', 'the', 'the actors'],
#  ['actors'],
#  ['actors'],
#  [],
#  ['actor',
#   'appropriate',
#   'exercise',
#   'latest',
#   'of',
#   'structure',
#   'the',
#   'the latest',
#   'to',
#   'vapid'],
#  ['latest', 'the', 'the latest'],
#  ['latest'],
#  ['actor', 'appropriate', 'exercise', 'of', 'structure', 'the', 'to', 'vapid'],
#  ['actor', 'appropriate', 'exercise', 'of', 'structure', 'the', 'to', 'vapid'],
#  ['actor', 'exercise', 'vapid'],
#  ['vapid'],
#  ['actor', 'exercise'],
#  ['actor'],
#  ['actor'],
#  ['exercise'],
#  ['appropriate', 'of', 'structure', 'the', 'to'],
#  ['appropriate', 'of', 'structure', 'the'],
#  ['appropriate', 'structure', 'the'],
#  ['appropriate'],
#  ['structure', 'the'],
#  ['structure'],
#  ['of'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['actually',
#   'and',
#   'but',
#   'constructed',
#   'inoffensive',
#   'it',
#   'more',
#   'narrative',
#   'on',
#   'rather',
#   'show',
#   'sweet',
#   'terms',
#   'than',
#   'those',
#   'well'],
#  ['actually',
#   'and',
#   'but',
#   'constructed',
#   'inoffensive',
#   'it',
#   'more',
#   'narrative',
#   'on',
#   'rather',
#   'show',
#   'sweet',
#   'terms',
#   'than',
#   'those',
#   'well'],
#  ['but', 'constructed', 'more', 'narrative', 'show', 'than', 'well'],
#  ['constructed', 'more', 'narrative', 'show', 'than', 'well'],
#  ['constructed', 'more', 'narrative', 'show', 'than', 'well'],
#  ['more'],
#  [],
#  ['constructed', 'narrative', 'show', 'than', 'well'],
#  ['show'],
#  ['constructed', 'narrative', 'than', 'well'],
#  ['than'],
#  ['constructed', 'narrative', 'well'],
#  ['constructed', 'well'],
#  ['narrative'],
#  ['actually',
#   'and',
#   'inoffensive',
#   'it',
#   'on',
#   'rather',
#   'sweet',
#   'terms',
#   'those'],
#  ['on', 'terms', 'those'],
#  ['on'],
#  ['terms', 'those'],
#  ['those'],
#  ['terms'],
#  ['actually', 'and', 'inoffensive', 'it', 'rather', 'sweet'],
#  ['actually', 'and', 'inoffensive', 'rather', 'sweet'],
#  ['actually', 'and', 'inoffensive', 'rather', 'sweet'],
#  ['actually', 'and', 'inoffensive'],
#  ['and', 'inoffensive'],
#  ['inoffensive'],
#  ['actually'],
#  ['rather', 'sweet'],
#  ['rather'],
#  ['action',
#   'action flick',
#   'flick',
#   'mill',
#   'more',
#   'more than',
#   'nothing',
#   'nothing more',
#   'of',
#   'of the',
#   'run',
#   'run of',
#   'than',
#   'the',
#   'the mill'],
#  ['action',
#   'action flick',
#   'flick',
#   'mill',
#   'more',
#   'more than',
#   'of',
#   'of the',
#   'run',
#   'run of',
#   'than',
#   'the',
#   'the mill'],
#  ['action',
#   'mill',
#   'more',
#   'more than',
#   'of',
#   'of the',
#   'run',
#   'run of',
#   'than',
#   'the',
#   'the mill'],
#  ['action',
#   'mill',
#   'of',
#   'of the',
#   'run',
#   'run of',
#   'than',
#   'the',
#   'the mill'],
#  ['action', 'mill', 'of', 'of the', 'run', 'run of', 'the', 'the mill'],
#  ['action', 'mill', 'of', 'of the', 'run', 'run of', 'the', 'the mill'],
#  ['mill', 'of', 'of the', 'run', 'run of', 'the', 'the mill'],
#  ['action'],
#  ['flick'],
#  ['aims',
#   'and',
#   'and ends',
#   'by',
#   'ends',
#   'ends up',
#   'for',
#   'indulgent',
#   'like',
#   'no',
#   'poetry',
#   'poetry and',
#   'satire',
#   'script',
#   'script that',
#   'self',
#   'self indulgent',
#   'that',
#   'up'],
#  ['aims',
#   'and',
#   'and ends',
#   'by',
#   'ends',
#   'ends up',
#   'for',
#   'indulgent',
#   'like',
#   'no',
#   'poetry',
#   'poetry and',
#   'satire',
#   'script',
#   'script that',
#   'self',
#   'self indulgent',
#   'that',
#   'up'],
#  ['by', 'indulgent', 'no', 'script', 'self', 'self indulgent'],
#  ['by', 'indulgent', 'no', 'script', 'self', 'self indulgent'],
#  ['no'],
#  [],
#  ['no'],
#  ['no'],
#  ['no'],
#  ['no'],
#  [],
#  [],
#  ['by', 'indulgent', 'script', 'self', 'self indulgent'],
#  ['indulgent', 'script', 'self', 'self indulgent'],
#  ['indulgent', 'script', 'self', 'self indulgent'],
#  ['indulgent', 'self', 'self indulgent'],
#  ['script'],
#  [],
#  ['aims',
#   'and',
#   'and ends',
#   'ends',
#   'ends up',
#   'for',
#   'like',
#   'poetry',
#   'poetry and',
#   'satire',
#   'that',
#   'up'],
#  ['aims',
#   'and',
#   'and ends',
#   'ends',
#   'ends up',
#   'for',
#   'like',
#   'poetry',
#   'poetry and',
#   'satire',
#   'up'],
#  ['aims', 'and', 'for', 'poetry', 'poetry and'],
#  ['aims', 'for', 'poetry'],
#  ['aims'],
#  ['for', 'poetry'],
#  ['poetry'],
#  ['ends', 'ends up', 'like', 'satire', 'up'],
#  ['ends', 'ends up', 'up'],
#  ['ends'],
#  ['up'],
#  ['like', 'satire'],
#  [],
#  ['like', 'satire'],
#  ['satire'],
#  ['age',
#   'and',
#   'and that',
#   'cartoon',
#   'computer',
#   'computer generated',
#   'early',
#   'feature',
#   'feel',
#   'feel like',
#   'first',
#   'for',
#   'for some',
#   'generated',
#   'ice',
#   'ice age',
#   'is',
#   'is the',
#   'like',
#   'makes',
#   'makes for',
#   'movies',
#   'movies and',
#   'on',
#   'other',
#   'other movies',
#   'pacing',
#   'some',
#   'that',
#   'that makes',
#   'the',
#   'the first',
#   'to',
#   'to feel'],
#  ['age',
#   'and',
#   'and that',
#   'cartoon',
#   'computer',
#   'computer generated',
#   'early',
#   'feature',
#   'feel',
#   'feel like',
#   'first',
#   'for',
#   'for some',
#   'generated',
#   'ice',
#   'ice age',
#   'is',
#   'is the',
#   'like',
#   'makes',
#   'makes for',
#   'movies',
#   'movies and',
#   'on',
#   'other',
#   'other movies',
#   'pacing',
#   'some',
#   'that',
#   'that makes',
#   'the',
#   'the first',
#   'to',
#   'to feel'],
#  ['age',
#   'and',
#   'cartoon',
#   'computer',
#   'computer generated',
#   'feature',
#   'feel',
#   'feel like',
#   'first',
#   'generated',
#   'ice',
#   'ice age',
#   'is',
#   'is the',
#   'like',
#   'movies',
#   'movies and',
#   'other',
#   'other movies',
#   'the',
#   'the first',
#   'to',
#   'to feel'],
#  ['age',
#   'cartoon',
#   'computer',
#   'computer generated',
#   'feature',
#   'feel',
#   'feel like',
#   'first',
#   'generated',
#   'ice',
#   'ice age',
#   'is',
#   'is the',
#   'like',
#   'movies',
#   'other',
#   'other movies',
#   'the',
#   'the first',
#   'to',
#   'to feel'],
#  ['age',
#   'cartoon',
#   'computer',
#   'computer generated',
#   'feature',
#   'feel',
#   'feel like',
#   'first',
#   'generated',
#   'ice',
#   'ice age',
#   'is',
#   'is the',
#   'like',
#   'movies',
#   'other',
#   'other movies',
#   'the',
#   'the first',
#   'to',
#   'to feel'],
#  ['age', 'ice', 'ice age'],
#  ['ice'],
#  ['age'],
#  ['cartoon',
#   'computer',
#   'computer generated',
#   'feature',
#   'feel',
#   'feel like',
#   'first',
#   'generated',
#   'is',
#   'is the',
#   'like',
#   'movies',
#   'other',
#   'other movies',
#   'the',
#   'the first',
#   'to',
#   'to feel'],
#  ['cartoon',
#   'computer',
#   'computer generated',
#   'feature',
#   'feel',
#   'feel like',
#   'first',
#   'generated',
#   'like',
#   'movies',
#   'other',
#   'other movies',
#   'the',
#   'the first',
#   'to',
#   'to feel'],
#  ['cartoon',
#   'computer',
#   'computer generated',
#   'feature',
#   'first',
#   'generated',
#   'the',
#   'the first'],
#  ['cartoon',
#   'computer',
#   'computer generated',
#   'feature',
#   'first',
#   'generated'],
#  ['first'],
#  ['cartoon', 'computer', 'computer generated', 'feature', 'generated'],
#  ['computer', 'computer generated', 'generated'],
#  ['cartoon', 'feature'],
#  ['feature'],
#  ['cartoon'],
#  ['feel',
#   'feel like',
#   'like',
#   'movies',
#   'other',
#   'other movies',
#   'to',
#   'to feel'],
#  ['feel', 'feel like', 'like', 'movies', 'other', 'other movies'],
#  ['feel'],
#  ['like', 'movies', 'other', 'other movies'],
#  ['movies', 'other', 'other movies'],
#  ['other'],
#  ['early',
#   'for',
#   'for some',
#   'makes',
#   'makes for',
#   'on',
#   'pacing',
#   'some',
#   'that',
#   'that makes'],
#  ['early', 'for', 'for some', 'makes', 'makes for', 'on', 'pacing', 'some'],
#  ['for', 'for some', 'makes', 'makes for', 'pacing', 'some'],
#  ['makes'],
#  ['for', 'for some', 'pacing', 'some'],
#  ['pacing', 'some'],
#  ['pacing'],
#  [],
#  ['pacing'],
#  ['early', 'on'],
#  ['early'],
#  ['but',
#   'but the',
#   'cliches',
#   'considerable',
#   'dash',
#   'going',
#   'going on',
#   'here',
#   'here but',
#   'little',
#   'makers',
#   'on',
#   'sense',
#   'serve',
#   'the',
#   'there',
#   'to',
#   'up',
#   'up the',
#   'very',
#   'very little',
#   'what',
#   'what going',
#   'with',
#   'with considerable'],
#  ['but',
#   'but the',
#   'cliches',
#   'considerable',
#   'dash',
#   'going',
#   'going on',
#   'here',
#   'here but',
#   'little',
#   'makers',
#   'on',
#   'sense',
#   'serve',
#   'the',
#   'there',
#   'to',
#   'up',
#   'up the',
#   'very',
#   'very little',
#   'what',
#   'what going',
#   'with',
#   'with considerable'],
#  ['but',
#   'going',
#   'going on',
#   'here',
#   'here but',
#   'little',
#   'on',
#   'sense',
#   'there',
#   'to',
#   'very',
#   'very little',
#   'what',
#   'what going'],
#  ['going',
#   'going on',
#   'here',
#   'little',
#   'on',
#   'sense',
#   'there',
#   'to',
#   'very',
#   'very little',
#   'what',
#   'what going'],
#  ['going',
#   'going on',
#   'here',
#   'little',
#   'on',
#   'sense',
#   'there',
#   'to',
#   'very',
#   'very little',
#   'what',
#   'what going'],
#  ['going',
#   'going on',
#   'here',
#   'little',
#   'on',
#   'sense',
#   'to',
#   'very',
#   'very little',
#   'what',
#   'what going'],
#  ['going',
#   'going on',
#   'here',
#   'little',
#   'on',
#   'sense',
#   'to',
#   'very',
#   'very little',
#   'what',
#   'what going'],
#  ['little', 'sense', 'very', 'very little'],
#  ['little', 'very', 'very little'],
#  ['going', 'going on', 'here', 'on', 'to', 'what', 'what going'],
#  ['going', 'going on', 'here', 'on', 'what', 'what going'],
#  ['going', 'going on', 'here', 'on'],
#  ['going', 'going on', 'here', 'on'],
#  ['going', 'going on', 'on'],
#  ['here'],
#  ['cliches',
#   'considerable',
#   'dash',
#   'makers',
#   'serve',
#   'the',
#   'up',
#   'up the',
#   'with',
#   'with considerable'],
#  ['makers', 'the'],
#  ['makers'],
#  ['cliches',
#   'considerable',
#   'dash',
#   'serve',
#   'the',
#   'up',
#   'up the',
#   'with',
#   'with considerable'],
#  ['serve', 'up'],
#  ['serve'],
#  ['cliches', 'considerable', 'dash', 'the', 'with', 'with considerable'],
#  ['cliches', 'the'],
#  ['cliches'],
#  ['considerable', 'dash', 'with', 'with considerable'],
#  ['considerable', 'dash'],
#  ['considerable'],
#  ['dash'],
#  ['different',
#   'film',
#   'film the',
#   'first',
#   'first film',
#   'followed',
#   'full',
#   'full monty',
#   'have',
#   'his',
#   'his first',
#   'monty',
#   'of',
#   'of his',
#   'should',
#   'should have',
#   'something',
#   'something different',
#   'success',
#   'the',
#   'the full',
#   'with',
#   'with something'],
#  [],
#  ['different',
#   'film',
#   'film the',
#   'first',
#   'first film',
#   'followed',
#   'full',
#   'full monty',
#   'have',
#   'his',
#   'his first',
#   'monty',
#   'of',
#   'of his',
#   'should',
#   'should have',
#   'something',
#   'something different',
#   'success',
#   'the',
#   'the full',
#   'with',
#   'with something'],
#  ['different',
#   'film',
#   'film the',
#   'first',
#   'first film',
#   'followed',
#   'full',
#   'full monty',
#   'have',
#   'his',
#   'his first',
#   'monty',
#   'of',
#   'of his',
#   'should',
#   'should have',
#   'something',
#   'something different',
#   'success',
#   'the',
#   'the full',
#   'with',
#   'with something'],
#  ['different',
#   'film',
#   'film the',
#   'first',
#   'first film',
#   'followed',
#   'full',
#   'full monty',
#   'have',
#   'his',
#   'his first',
#   'monty',
#   'of',
#   'of his',
#   'something',
#   'something different',
#   'success',
#   'the',
#   'the full',
#   'with',
#   'with something'],
#  ['different',
#   'film',
#   'film the',
#   'first',
#   'first film',
#   'followed',
#   'full',
#   'full monty',
#   'his',
#   'his first',
#   'monty',
#   'of',
#   'of his',
#   'something',
#   'something different',
#   'success',
#   'the',
#   'the full',
#   'with',
#   'with something'],
#  ['film',
#   'film the',
#   'first',
#   'first film',
#   'followed',
#   'full',
#   'full monty',
#   'his',
#   'his first',
#   'monty',
#   'of',
#   'of his',
#   'success',
#   'the',
#   'the full'],
#  ['followed'],
#  ['film',
#   'film the',
#   'first',
#   'first film',
#   'full',
#   'full monty',
#   'his',
#   'his first',
#   'monty',
#   'of',
#   'of his',
#   'success',
#   'the',
#   'the full'],
#  ['success', 'the'],
#  ['success'],
#  [],
#  ['success'],
#  ['film',
#   'film the',
#   'first',
#   'first film',
#   'full',
#   'full monty',
#   'his',
#   'his first',
#   'monty',
#   'of',
#   'of his',
#   'the',
#   'the full'],
#  ['film',
#   'film the',
#   'first',
#   'first film',
#   'full',
#   'full monty',
#   'his',
#   'his first',
#   'monty',
#   'the',
#   'the full'],
#  ['film',
#   'film the',
#   'first',
#   'first film',
#   'full',
#   'full monty',
#   'his',
#   'his first',
#   'monty',
#   'the',
#   'the full'],
#  ['film', 'first', 'first film', 'his', 'his first'],
#  ['film', 'first', 'first film', 'his', 'his first'],
#  ['film', 'first', 'first film'],
#  ['full', 'full monty', 'monty', 'the', 'the full'],
#  ['full', 'full monty', 'monty'],
#  ['full'],
#  ['monty'],
#  ['different', 'something', 'something different', 'with', 'with something'],
#  ['different', 'something', 'something different'],
#  ['different'],
#  ['as',
#   'avoid',
#   'easily',
#   'forces',
#   'heroes',
#   'horror',
#   'horror movies',
#   'movies',
#   'of',
#   're',
#   'serve',
#   'terror',
#   'that',
#   'the',
#   'they',
#   'they re',
#   'to',
#   'to avoid',
#   'try',
#   'try to',
#   'whatever'],
#  ['they'],
#  ['as',
#   'avoid',
#   'easily',
#   'forces',
#   'heroes',
#   'horror',
#   'horror movies',
#   'movies',
#   'of',
#   're',
#   'serve',
#   'terror',
#   'that',
#   'the',
#   'to',
#   'to avoid',
#   'try',
#   'try to',
#   'whatever'],
#  ['as',
#   'avoid',
#   'easily',
#   'forces',
#   'heroes',
#   'horror',
#   'horror movies',
#   'movies',
#   'of',
#   're',
#   'serve',
#   'terror',
#   'that',
#   'the',
#   'to',
#   'to avoid',
#   'try',
#   'try to',
#   'whatever'],
#  ['re'],
#  ['as',
#   'avoid',
#   'easily',
#   'forces',
#   'heroes',
#   'horror',
#   'horror movies',
#   'movies',
#   'of',
#   'serve',
#   'terror',
#   'that',
#   'the',
#   'to',
#   'to avoid',
#   'try',
#   'try to',
#   'whatever'],
#  ['easily', 'forces', 'the'],
#  ['easily', 'forces'],
#  ['easily'],
#  [],
#  ['easily'],
#  ['easily'],
#  ['easily'],
#  [],
#  ['forces'],
#  ['as',
#   'avoid',
#   'heroes',
#   'horror',
#   'horror movies',
#   'movies',
#   'of',
#   'serve',
#   'terror',
#   'that',
#   'the',
#   'to',
#   'to avoid',
#   'try',
#   'try to',
#   'whatever'],
#  ['as',
#   'avoid',
#   'heroes',
#   'horror',
#   'horror movies',
#   'movies',
#   'of',
#   'serve',
#   'terror',
#   'the',
#   'to',
#   'to avoid',
#   'try',
#   'try to',
#   'whatever'],
#  ['as',
#   'avoid',
#   'heroes',
#   'horror',
#   'horror movies',
#   'movies',
#   'of',
#   'terror',
#   'the',
#   'to',
#   'to avoid',
#   'try',
#   'try to',
#   'whatever'],
#  ['avoid',
#   'heroes',
#   'horror',
#   'horror movies',
#   'movies',
#   'of',
#   'terror',
#   'the',
#   'to',
#   'to avoid',
#   'try',
#   'try to',
#   'whatever'],
#  ['whatever'],
#  ['avoid',
#   'heroes',
#   'horror',
#   'horror movies',
#   'movies',
#   'of',
#   'terror',
#   'the',
#   'to',
#   'to avoid',
#   'try',
#   'try to'],
#  ['terror'],
#  ['avoid',
#   'heroes',
#   'horror',
#   'horror movies',
#   'movies',
#   'of',
#   'the',
#   'to',
#   'to avoid',
#   'try',
#   'try to'],
#  ['heroes', 'horror', 'horror movies', 'movies', 'of', 'the'],
#  ['heroes', 'the'],
#  ['heroes'],
#  ['horror', 'horror movies', 'movies', 'of'],
#  ['horror', 'horror movies', 'movies'],
#  ['horror'],
#  ['avoid', 'to', 'to avoid', 'try', 'try to'],
#  ...]

# %%
x_test = vectorizer.transform(test['Phrase'])
x_test
# Out:
# <66292x10000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 421216 stored elements in Compressed Sparse Row format>

# %%
y_train=train['Sentiment']

print(y_train.shape)
y_train.head()
# Out:
# (156060,)
# PhraseId
# 1    1
# 2    2
# 3    2
# 4    2
# 5    2
# Name: Sentiment, dtype: int64

# %% [markdown]
# ## Score

# %%
from sklearn.linear_model import SGDClassifier

model = SGDClassifier(random_state=37)
model
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=37, shuffle=True,
#        tol=None, verbose=0, warm_start=False)

# %%
from sklearn.cross_validation import cross_val_predict

y_predict = cross_val_predict(model,x_train,y_train,cv=5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
from sklearn.metrics import accuracy_score

score = accuracy_score(y_train,y_predict)
print("Score = {0:.5f}".format(score))
# Out:
# Score = 0.57656

# %%
import numpy as np

result = train.copy()
result['Sentiment(predict)'] = y_predict
result['Difference(Phrase)'] = np.abs(y_train - y_predict)

print(result.shape)
result.head()
# Out:
# (156060, 6)
#           SentenceId                                             Phrase  \
# PhraseId
# 1                  1  A series of escapades demonstrating the adage ...
# 2                  1  A series of escapades demonstrating the adage ...
# 3                  1                                           A series
# 4                  1                                                  A
# 5                  1                                             series
#
#           Sentiment                                     Phrase(origin)  \
# PhraseId
# 1                 1  A series of escapades demonstrating the adage ...
# 2                 2  A series of escapades demonstrating the adage ...
# 3                 2                                           A series
# 4                 2                                                  A
# 5                 2                                             series
#
#           Sentiment(predict)  Difference(Phrase)
# PhraseId
# 1                          1                   0
# 2                          2                   0
# 3                          2                   0
# 4                          2                   0
# 5                          2                   0

# %%
sentiment = result.groupby("SentenceId")["Difference(Phrase)"].mean()
print(sentiment.shape)
sentiment.head()
# Out:
# (8529,)
# SentenceId
# 1    0.222222
# 2    0.444444
# 3    0.314286
# 4    0.675000
# 5    0.800000
# Name: Difference(Phrase), dtype: float64

# %%
def find_sentiment(sentence_id):
    return sentiment.loc[sentence_id]

def find_words(phraseId_id):
    return words_list[phraseId_id-1]

result["Difference(Sentence)"] = result["SentenceId"].apply(find_sentiment)
result["Idx"] = result.index
result["Keywords"] = result['Idx'].apply(find_words)
result = result.sort_values(by="Difference(Sentence)",ascending=False)

print(result.shape)
result.head()
# Out:
# (156060, 9)
#           SentenceId                                             Phrase  \
# PhraseId
# 82700           4270     one of the biggest disappointments of the year
# 82703           4270                        the biggest disappointments
# 82702           4270            the biggest disappointments of the year
# 82701           4270         of the biggest disappointments of the year
# 82699           4270  is one of the biggest disappointments of the year
#
#           Sentiment                                     Phrase(origin)  \
# PhraseId
# 82700             1     one of the biggest disappointments of the year
# 82703             1                        the biggest disappointments
# 82702             1            the biggest disappointments of the year
# 82701             0         of the biggest disappointments of the year
# 82699             0  is one of the biggest disappointments of the year
#
#           Sentiment(predict)  Difference(Phrase)  Difference(Sentence)    Idx  \
# PhraseId
# 82700                      4                   3                 2.625  82700
# 82703                      2                   1                 2.625  82703
# 82702                      2                   1                 2.625  82702
# 82701                      2                   2                 2.625  82701
# 82699                      4                   4                 2.625  82699
#
#                                                    Keywords
# PhraseId
# 82700     [biggest, of, of the, one, one of, the, the bi...
# 82703                           [biggest, the, the biggest]
# 82702     [biggest, of, of the, the, the biggest, the ye...
# 82701     [biggest, of, of the, the, the biggest, the ye...
# 82699     [biggest, is, is one, of, of the, one, one of,...

# %%
words_list[4270]
# Out:
# ['diversion',
#  'eight',
#  'eight legged',
#  'entertaining',
#  'freaks',
#  'legged',
#  'legged freaks',
#  'makes',
#  'perfectly',
#  'summer']

# %%
result[0:1000].to_csv("result.csv")

# %%
vocabulary = vectorizer.get_feature_names()
vocabulary[0:3]
# Out:
# ['000', '10', '10 minutes']

# %%
pd.DataFrame(vocabulary,columns=["word"]).to_csv("vocabulary.csv")

# %%
result[result['Phrase'].str.contains("can not recommend")]
# Out:
#           SentenceId                                             Phrase  \
# PhraseId
# 79349           4087                           I can not recommend it .
# 80730           4158                        can not recommend it enough
# 79350           4087                             can not recommend it .
# 80729           4158                      can not recommend it enough .
# 80728           4158               simply can not recommend it enough .
# 80727           4158             I simply can not recommend it enough .
# 22224            998  I admire it and yet can not recommend it , bec...
# 22230            998  can not recommend it , because it overstays it...
# 22226            998  admire it and yet can not recommend it , becau...
# 22225            998  admire it and yet can not recommend it , becau...
# 22229            998  yet can not recommend it , because it overstay...
# 36734           1740                     certainly can not recommend it
# 36735           1740                               can not recommend it
# 36733           1740                   I certainly can not recommend it
# 36727           1740  It 's mildly amusing , but I certainly can not...
# 36726           1740  It 's mildly amusing , but I certainly can not...
#
#           Sentiment                                     Phrase(origin)  \
# PhraseId
# 79349             0                            I ca n't recommend it .
# 80730             4                         ca n't recommend it enough
# 79350             0                              ca n't recommend it .
# 80729             4                       ca n't recommend it enough .
# 80728             4                simply ca n't recommend it enough .
# 80727             3              I simply ca n't recommend it enough .
# 22224             1  I admire it and yet can not recommend it , bec...
# 22230             1  can not recommend it , because it overstays it...
# 22226             2  admire it and yet can not recommend it , becau...
# 22225             1  admire it and yet can not recommend it , becau...
# 22229             1  yet can not recommend it , because it overstay...
# 36734             0                      certainly ca n't recommend it
# 36735             0                                ca n't recommend it
# 36733             1                    I certainly ca n't recommend it
# 36727             2  It 's mildly amusing , but I certainly ca n't ...
# 36726             1  It 's mildly amusing , but I certainly ca n't ...
#
#           Sentiment(predict)  Difference(Phrase)  Difference(Sentence)  \
# PhraseId
# 79349                      2                   2              2.000000
# 80730                      2                   2              2.000000
# 79350                      2                   2              2.000000
# 80729                      2                   2              2.000000
# 80728                      0                   4              2.000000
# 80727                      0                   3              2.000000
# 22224                      3                   2              1.058824
# 22230                      3                   2              1.058824
# 22226                      3                   1              1.058824
# 22225                      3                   2              1.058824
# 22229                      3                   2              1.058824
# 36734                      3                   3              1.000000
# 36735                      1                   1              1.000000
# 36733                      3                   2              1.000000
# 36727                      3                   1              1.000000
# 36726                      3                   2              1.000000
#
#                                                    Keywords
# PhraseId
# 79349     [an, an artist, artist, artist who, is, is sim...
# 80730     [all, enveloping, experience, movie, movie exp...
# 79350     [an, an artist, artist, artist who, is, is sim...
# 80729     [all, enveloping, experience, movie, movie exp...
# 80728     [all, enveloping, experience, movie, movie exp...
# 80727     [all, enveloping, experience, movie, movie exp...
# 22224                                              [horror]
# 22230                                              [horror]
# 22226                                              [horror]
# 22225                                              [horror]
# 22229                                              [horror]
# 36734                               [cinematic, gratuitous]
# 36735                               [cinematic, gratuitous]
# 36733                               [cinematic, gratuitous]
# 36727                               [cinematic, gratuitous]
# 36726                               [cinematic, gratuitous]
